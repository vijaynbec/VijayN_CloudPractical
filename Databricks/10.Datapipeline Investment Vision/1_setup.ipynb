# %% [markdown]
# ### Create a Schema in Unity Catalog, volume for file storage

# %%
# %sql
create schema if not exists `investment_vision`;

# %%
# %sql
select current_catalog(), current_schema();

# %%
# %sql
use schema `investment_vision`;

# %%
# %sql
select current_catalog(), current_schema();

# %%
# %sql
create volume if not exists files_volume;

# %%
display(dbutils.fs.ls('/Volumes/workspace/investment_vision/files_volume'))
